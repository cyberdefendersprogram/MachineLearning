# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("ssl.csv")

# %%
#DataFrame with columns
columns = pd.DataFrame(list(df.columns.values[1:]))

#DataFrame with data types
data_types = pd.DataFrame(df.dtypes, columns=['Data Type'])

#DataFrame with Count
data_count = pd.DataFrame(df.count(), columns=['Count'])

#DataFrame with unique values
unique_value_counts = pd.DataFrame(columns=['Unique Values'])
for v in list(df.columns.values):
    unique_value_counts.loc[v] = [df[v].nunique()]

missing_data_counts = pd.DataFrame(df.isnull().sum(), columns=['Missing Values'])
data_quality_report = data_types.join(data_count).join(unique_value_counts).join(missing_data_counts)
print('Data Quality Report')
data_quality_report
# Out:
# Data Quality Report
#                       Data Type  Count Unique Values  Missing Values
# ts                      float64   3749          2600               0
# uid                      object   3749          2600               0
# id.orig_h                object   3749           126               0
# id.orig_p                 int64   3749           469               0
# id.resp_h                object   3749           910               0
# id.resp_p                 int64   3749             3               0
# version                  object   2673             5            1076
# cipher                   object   2673             6            1076
# server_name              object      1             1            3748
# session_id               object    477           317            3272
# subject                  object   2209           198            1540
# issuer_subject           object   2209            56            1540
# not_valid_before        float64   2209           413            1540
# not_valid_after         float64   2209           301            1540
# last_alert               object   1194           263            2555
# client_subject          float64      0             0            3749
# client_issuer_subject   float64      0             0            3749
# cert_hash                object   2209           422            1540
# validation_status        object   2209             3            1540
