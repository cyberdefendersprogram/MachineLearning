# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("ssl.csv")

# %%
#DataFrame with columns
columns = pd.DataFrame(list(df.columns.values[1:]))

#DataFrame with data types
data_types = pd.DataFrame(df.dtypes, columns=['Data Type'])

#DataFrame with Count
data_count = pd.DataFrame(df.count(), columns=['Count'])

#DataFrame with unique values
unique_value_counts = pd.DataFrame(columns=['Unique Values'])
for v in list(df.columns.values):
    unique_value_counts.loc[v] = [df[v].nunique()]

missing_data_counts = pd.DataFrame(df.isnull().sum(), columns=['Missing Values'])
data_quality_report = data_types.join(data_count).join(unique_value_counts).join(missing_data_counts)
print('Data Quality Report')
data_quality_report
# Out:
# Data Quality Report
#                       Data Type  Count Unique Values  Missing Values
# ts                      float64   2130          1511               0
# uid                      object   2130          1511               0
# id.orig_h                object   2130           122               0
# id.orig_p                 int64   2130           261               0
# id.resp_h                object   2130           654               0
# id.resp_p                 int64   2130             1               0
# version                  object   1502             3             628
# cipher                   object   1502             4             628
# server_name             float64      0             0            2130
# session_id               object    332           191            1798
# subject                  object   1220           155             910
# issuer_subject           object   1220            46             910
# not_valid_before        float64   1220           343             910
# not_valid_after         float64   1220           251             910
# last_alert               object    648           127            1482
# client_subject          float64      0             0            2130
# client_issuer_subject   float64      0             0            2130
# cert_hash                object   1220           349             910
# validation_status        object   1220             3             910
