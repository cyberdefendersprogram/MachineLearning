# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("notice.csv")

# %%
#DataFrame with columns
columns = pd.DataFrame(list(df.columns.values[1:]))

#DataFrame with data types
data_types = pd.DataFrame(df.dtypes, columns=['Data Type'])

#DataFrame with Count
data_count = pd.DataFrame(df.count(), columns=['Count'])

#DataFrame with unique values
unique_value_counts = pd.DataFrame(columns=['Unique Values'])
for v in list(df.columns.values):
    unique_value_counts.loc[v] = [df[v].nunique()]

missing_data_counts = pd.DataFrame(df.isnull().sum(), columns=['Missing Values'])
data_quality_report = data_types.join(data_count).join(unique_value_counts).join(missing_data_counts)
print('Data Quality Report')
data_quality_report
# Out:
# Data Quality Report
#                              Data Type  Count Unique Values  Missing Values
# ts                             float64   2606          2341               0
# uid                             object   2563          2078              43
# id.orig_h                       object   2563           128              43
# id.orig_p                      float64   2563           150              43
# id.resp_h                       object   2563           620              43
# id.resp_p                      float64   2563            14              43
# fuid                            object   2538          2538              68
# file_mime_type                  object   2538             5              68
# file_desc                       object   2538          1796              68
# proto                           object   2606             1               0
# note                            object   2606             3               0
# msg                             object   2606           847               0
# sub                             object   2606           815               0
# src                             object   2606           128               0
# dst                             object   2563           620              43
# p                                int64   2606            20               0
# n                              float64      0             0            2606
# peer_descr                      object   2606             1               0
# actions                         object   2606             1               0
# suppress_for                   float64   2606             1               0
# dropped                         object   2606             1               0
# remote_location.country_code   float64      0             0            2606
# remote_location.region         float64      0             0            2606
# remote_location.city           float64      0             0            2606
# remote_location.latitude       float64      0             0            2606
# remote_location.longitude      float64      0             0            2606
