# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("dns.csv")

# %%
#DataFrame with columns
columns = pd.DataFrame(list(df.columns.values[1:]))

#DataFrame with data types
data_types = pd.DataFrame(df.dtypes, columns=['Data Type'])

#DataFrame with Count
data_count = pd.DataFrame(df.count(), columns=['Count'])

#DataFrame with unique values
unique_value_counts = pd.DataFrame(columns=['Unique Values'])
for v in list(df.columns.values):
    unique_value_counts.loc[v] = [df[v].nunique()]

missing_data_counts = pd.DataFrame(df.isnull().sum(), columns=['Missing Values'])
data_quality_report = data_types.join(data_count).join(unique_value_counts).join(missing_data_counts)
print('Data Quality Report')
data_quality_report
# Out:
# Data Quality Report
#             Data Type  Count Unique Values  Missing Values
# ts            float64  85208         79681               0
# uid            object  85208         35584               0
# id.orig_h      object  85208           128               0
# id.orig_p       int64  85208          1602               0
# id.resp_h      object  85208           104               0
# id.resp_p       int64  85208             1               0
# proto          object  85208             2               0
# trans_id        int64  85208         29341               0
# query          object  76658         28643            8550
# qclass        float64  76658             1            8550
# qclass_name    object  76658             1            8550
# qtype         float64  76658             6            8550
# qtype_name     object  76658             6            8550
# rcode         float64  70387             3           14821
# rcode_name     object  70387             3           14821
# AA             object  85208             2               0
# TC             object  85208             1               0
# RD             object  85208             2               0
# RA             object  85208             2               0
# Z               int64  85208             1               0
# answers        object  63974         34627           21234
# TTLs           object  63974         31124           21234
# rejected       object  85208             2               0
